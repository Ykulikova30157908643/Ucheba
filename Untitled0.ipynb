# %% [markdown]
# <a href="https://colab.research.google.com/github/Ykulikova30157908643/Ucheba/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kopilka = 0
month = 0
while kopilka < 1000000:
  kopilka = kopilka+10000
  month = month+1
print(month)
# Out:
# 100

# %%
for i in range(1, 10):
  print(i, end=" ")
# Out:
# 1 3 5 7 9

# %%
for x in range(1, 11):
  y=x**2
  print(y)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
A=[0, 1, 2, 3, 5, 6, 10, 13]

# %%
print(A)
# Out:
# [0, 1, 2, 3, 5, 6, 10, 13]

# %%
for i in range(len(A)):
  print (A[i])
# Out:
# 0
# 1
# 2
# 3
# 5
# 6
# 10
# 13

# %%
len(A)
# Out:
# 8

# %%
for i in range(len(A), 5):
  print (A[i])

# %%
N=5
C=[0]*N
for i in range(N):
  C[i]=i**2
print(C)
# Out:
# [0, 1, 4, 9, 16]

# %%
char='А'
unicode_value=ord(char)
print(unicode_value)
# Out:
# 1040

# %%
R={'PY5768':'New York','TY0492':'Moscow'}

# %%
input('Введите ключ очередного элемента словаря')
# Out:
# Введите ключ очередного элемента словаря50
# '50'

# %%
import pandas as pd
my_series = pd.Series([5, 6, 7, 8, 9, 10])
print(my_series)
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    10
# dtype: int64

# %%
my_series[0:2]
# Out:
# 0    5
# 1    6
# dtype: int64

# %%
my_series2 = pd.Series([5, 6, 7, 8, 9, 10], index=['a', 'b', 'c', 'd', 'e', 'f'])
my_series2['f']
# Out:
# 10

# %%
my_series2[['a','b','f']]
# Out:
# a     5
# b     6
# f    10
# dtype: int64

# %%
a = []
for i in range(0, 4):
  a.append(i*2+3)
my_series3 = pd.Series(a)
my_series3.index = ['Первый', 'Второй', 'Третий', 'Четвертый']
my_series3
# Out:
# Первый       3
# Второй       5
# Третий       7
# Четвертый    9
# dtype: int64

# %%
data=pd.DataFrame([my_series,my_series*2,my_series*3])
data
# Out:
#     0   1   2   3   4   5
# 0   5   6   7   8   9  10
# 1  10  12  14  16  18  20
# 2  15  18  21  24  27  30

# %%
dictionary = {'Name': ['Alice', 'Bob', 'Charlie'],
  'Age': [25, 30, 28],
  'City': ['New York', 'Los Angeles', 'Chicago']}
df = pd.DataFrame(dictionary)
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   28      Chicago

# %%
A=['Kazakhstan', 17.04, 2724902]
B=['Russia',  143.5, 17125191]
C=['Belarus', 9.5, 207600]
D=["country", "population", "square"]
data = pd.DataFrame(data = [A, B, C], columns=D)
data
# Out:
#       country  population    square
# 0  Kazakhstan       17.04   2724902
# 1      Russia      143.50  17125191
# 2     Belarus        9.50    207600

# %%
data["country"]
# Out:
# 0    Kazakhstan
# 1        Russia
# 2       Belarus
# Name: country, dtype: object

# %%
data[["country","population"]]
# Out:
#       country  population
# 0  Kazakhstan       17.04
# 1      Russia      143.50
# 2     Belarus        9.50

# %%
data.loc[1]
# Out:
# country         Russia
# population       143.5
# square        17125191
# Name: 1, dtype: object

# %%
data.loc[data["country"] == "Russia"]
# Out:
#   country  population    square
# 1  Russia       143.5  17125191

# %%
import pandas as pd
pd.read_csv("http://intersyn.net/Churn.csv")
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data = pd.read_csv("http://intersyn.net/Churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
T=5
P=[]
for i in range(T):
  P.append(i**2)
print(P)
# Out:
# [0, 1, 4, 9, 16]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  9091.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800     4.997690
# std     2886.89568  7.193619e+04     96.653299     10.487806     2.894723
# min        1.00000  1.556570e+07    350.000000     18.000000     0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000     2.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df = pd.read_csv("shootings_USA.csv")

# %%
df
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4840  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4841  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4842  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4843  5921      William Slyter  2020-06-13              shot         gun
# 4844  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4845 entries, 0 to 4844
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4845 non-null   int64
#  1   name                     4845 non-null   object
#  2   date                     4845 non-null   object
#  3   manner_of_death          4845 non-null   object
#  4   armed                    4845 non-null   object
#  5   age                      4845 non-null   float64
#  6   gender                   4845 non-null   object
#  7   race                     4845 non-null   object
#  8   city                     4845 non-null   object
#  9   state                    4845 non-null   object
#  10  signs_of_mental_illness  4845 non-null   bool
#  11  threat_level             4845 non-null   object
#  12  flee                     4845 non-null   object
#  13  body_camera              4845 non-null   bool
# ...

# %%
took = pd.read_excel("Russia.xlsx")

# %%
took.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 11 columns):
#  #   Column                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                        --------------  -----
#  0   Наименование                                                                                                                  85 non-null     object
#  1   Средняя продолжительность жизни ЖЕНЩИН                                                                                        85 non-null     float64
#  2   Младенческая смертность, число детей, умерших в возрасте до 1 года, на 1000 родившихся живыми                                85 non-null     float64
# ...

# %%
took.describe()
# Out:
#        Средняя продолжительность жизни ЖЕНЩИН  \
# count                               85.000000
# mean                                76.038824
# std                                  1.899839
# min                                 68.810000
# 25%                                 75.270000
# 50%                                 75.940000
# 75%                                 76.890000
# max                                 84.610000
#
#        Младенческая смертность, число детей, умерших в возрасте до 1 года, на 1000 родившихся живыми  \
# count                                          85.000000
# mean                                            4.709412
# std                                             1.580131
# min                                             2.100000
# 25%                                             3.700000
# 50%                                             4.400000
# 75%                                             5.500000
# ...

# %%
yt = pd.read_json("EmployeeData.json")
yt
# Out:
#       id                 name                               email  \
# 0   4051                manoj                     manoj@gmail.com
# 1   4050               pankaj                        p1@gmail.com
# 2   3050           Neeraj1993   neeraj.singh@adequateinfosoft.com
# 3   3049               Sophia                    sophia@gmail.com
# 4   3048          Raju Prasad                 raju.nsit@gmail.com
# 5   3047    Ankiish Thapliyal       thapliyalankiish958@gmail.com
# 6   3046      Aryan Thapliyal            ashithewarrior@gmail.com
# 7   3045               shivam                    shivam@gmail.com
# 8   3044       Navya Upadhyay            navya.adequate@gmail.com
# 9   3043           Ritu singh         ritusinghadequate@gmail.com
# 10  3042                 faiz              faizadequate@gmail.com
# 11  3041        Martin Wilson          ravencomputer667@gmail.com
# 12  3040         Shweta Singh          amelia.claire.hi@gmail.com
# ...

# %%
yt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   55 non-null     int64
#  1   name                 55 non-null     object
#  2   email                55 non-null     object
#  3   password             55 non-null     object
#  4   about                23 non-null     object
#  5   token                55 non-null     object
#  6   country              0 non-null      float64
#  7   location             22 non-null     object
#  8   lng                  55 non-null     float64
#  9   lat                  55 non-null     float64
#  10  dob                  22 non-null     object
#  11  gender               55 non-null     int64
#  12  userType             55 non-null     int64
#  13  userStatus           55 non-null     int64
#  14  profilePicture       25 non-null     object
# ...

# %%
yt.describe()
# Out:
#                 id  country        lng        lat     gender  userType  \
# count    55.000000      0.0  55.000000  55.000000  55.000000      55.0
# mean   2479.763636      NaN   0.159958   0.106089   0.545455       1.0
# std     847.789063      NaN   1.186282   0.786775   0.812362       0.0
# min       2.000000      NaN   0.000000   0.000000   0.000000       1.0
# 25%    2011.500000      NaN   0.000000   0.000000   0.000000       1.0
# 50%    3024.000000      NaN   0.000000   0.000000   0.000000       1.0
# 75%    3038.500000      NaN   0.000000   0.000000   1.000000       1.0
# max    4051.000000      NaN   8.797700   5.834876   3.000000       1.0
#
#        userStatus    livelng    livelat  creditBalance     myCash
# count        55.0  55.000000  55.000000      55.000000  55.000000
# mean          1.0  36.579483  13.533546      35.272727   0.654545
# std           0.0  38.988305  14.424753      62.006408   4.854239
# ...

# %%
import pandas as pd
df = pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})
df
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  2  1

# %%
df.drop(1, axis=0, inplace=True)
df
# Out:
#    y
# 0  2
# 2  1

# %%
df1 = pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})
df2 = pd.DataFrame({'x':[3,1,2], 'y':[0,2,2]})
print (df1>=df2)
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False
